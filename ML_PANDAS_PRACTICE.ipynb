# %% [markdown]
# <h1> <center> <u> ML PANDAS PRACTICE </center> </h1> </u>

# %% [markdown]
# ### Dataset Link
# https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
food=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\FoodFacts\\en.openfoodfacts.org.products.tsv",delimiter="\t")
# Out:
# C:\Users\viswa\AppData\Local\Temp\ipykernel_12380\564778064.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food=pd.read_csv("C:\\Users\\viswa\\Data Science and ML\\Datasets\\FoodFacts\\en.openfoodfacts.org.products.tsv",delimiter="\t")

# %%
food
# Out:
#                  code                                                url  \
# 0                3087  http://world-en.openfoodfacts.org/product/0000...
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
#See the first 5 entries
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
food.shape[0] #prints number of observation
# Out:
# 356027

# %%
food.shape[1] #prints number of columns
# Out:
# 163

# %%
food.columns #Print column names
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
food.columns[104] # What is the name of 105th column?
# Out:
# '-glucose_100g'

# %%
food.dtypes[104] # What is the type of the observations of the 105th column?
# Out:
# dtype('float64')

# %%
food.index # How is the dataset indexed?
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %%
food["product_name"][18] # What is the product name of the 19th observation?
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
food.iloc[19:20,7:8] #rows columns
# Out:
#           product_name
# 19  Organic Oat Groats

# %%
food.iloc[19:20,food.columns=="product_name"]
# Out:
#           product_name
# 19  Organic Oat Groats

# %%
# How many columns in the dataset tend to have null values?
null_columns = food.isnull().sum()
null_columns[null_columns>0].count()
null_column_values = null_columns[null_columns>0]
len(null_column_values)
# Out:
# 161

# %%
nc=food.isnull().sum() # Find the number of null values present under each column?
nc
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %%
# Create a dictionary with keys to be column names in the dataset and values to number of null values under each column. Print the dictionary by iterating through its elements using a for loop.  
null_columns = food.isnull().sum()  
null_columns[null_columns>0].count()
null_column_values = null_columns[null_columns>0]
null_column_values
mydict={}
for i in range(food.shape[1]):
  mydict[food.columns[i]]=null_columns[i]
mydict
# Out:
# {'code': 26,
#  'url': 26,
#  'creator': 3,
#  'created_t': 3,
#  'created_datetime': 10,
#  'last_modified_t': 0,
#  'last_modified_datetime': 0,
#  'product_name': 17512,
#  'generic_name': 298313,
#  'quantity': 236742,
#  'packaging': 266068,
#  'packaging_tags': 266068,
#  'brands': 29050,
#  'brands_tags': 29070,
#  'categories': 252728,
#  'categories_tags': 252752,
#  'categories_en': 252726,
#  'origins': 330977,
#  'origins_tags': 331015,
#  'manufacturing_places': 314019,
#  'manufacturing_places_tags': 314026,
#  'labels': 296929,
#  'labels_tags': 296849,
#  'labels_en': 296823,
#  'emb_codes': 323537,
#  'emb_codes_tags': 323541,
#  'first_packaging_code_geo': 335155,
#  'cities': 356001,
#  'cities_tags': 333525,
#  'purchase_places': 289462,
#  'stores': 298326,
#  'countries': 275,
#  'countries_tags': 275,
#  'countries_en': 275,
#  'ingredients_text': 72134,
#  'allergens': 318851,
#  'allergens_en': 356007,
#  'traces': 327606,
#  'traces_tags': 327633,
# ...

# %%
# Display the values associated with all columns from row 108 to 208?
food.iloc[108:209,:]
# Out:
#          code                                                url  \
# 108     36252  http://world-en.openfoodfacts.org/product/0000...
# 109     36269  http://world-en.openfoodfacts.org/product/0000...
# 110     36276  http://world-en.openfoodfacts.org/product/0000...
# 111     36986  http://world-en.openfoodfacts.org/product/0000...
# 112     38058  http://world-en.openfoodfacts.org/product/0000...
# ..        ...                                                ...
# 204  20043087  http://world-en.openfoodfacts.org/product/0000...
# 205  20043124  http://world-en.openfoodfacts.org/product/0000...
# 206  20043131  http://world-en.openfoodfacts.org/product/0000...
# 207  20044015  http://world-en.openfoodfacts.org/product/0000...
# 208  20044480  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime last_modified_t  \
# 108          tacinte  1422221701  2015-01-25T21:35:01Z      1494824741
# ...
