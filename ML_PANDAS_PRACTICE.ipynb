# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d openfoodfacts/world-food-facts
# Out:
# Downloading world-food-facts.zip to /content
#  91% 99.0M/109M [00:01<00:00, 93.6MB/s]
# 100% 109M/109M [00:01<00:00, 93.3MB/s]

# %%
from zipfile import ZipFile
dataset = '/content/world-food-facts.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
food=pd.read_csv("/content/en.openfoodfacts.org.products.tsv",delimiter="\t")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-66-70422f93efa8> in <cell line: 1>()
# ----> 1 food=pd.read_csv("/content/en.openfoodfacts.org.products.tsv",delimiter="\t")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 163 fields in line 356353, saw 252

# %%
food
# Out:
#               code                                                url  \
# 0             3087  http://world-en.openfoodfacts.org/product/0000...
# 1             4530  http://world-en.openfoodfacts.org/product/0000...
# 2             4559  http://world-en.openfoodfacts.org/product/0000...
# 3            16087  http://world-en.openfoodfacts.org/product/0000...
# 4            16094  http://world-en.openfoodfacts.org/product/0000...
# ...            ...                                                ...
# 65136  52603054560  http://world-en.openfoodfacts.org/product/0052...
# 65137  52603054614  http://world-en.openfoodfacts.org/product/0052...
# 65138  52603054621  http://world-en.openfoodfacts.org/product/0052...
# 65139  52603054645  http://world-en.openfoodfacts.org/product/0052...
# 65140  52603054652  http://world-en.openfoodfacts.org/product/0052...
#
#                           creator   created_t      created_datetime  \
# 0      openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2                 usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3                 usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4                 usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                           ...         ...                   ...
# 65136             usda-ndb-import  1489050383  2017-03-09T09:06:23Z
# 65137             usda-ndb-import  1489057900  2017-03-09T11:11:40Z
# 65138             usda-ndb-import  1489057828  2017-03-09T11:10:28Z
# 65139             usda-ndb-import  1489061505  2017-03-09T12:11:45Z
# 65140             usda-ndb-import  1489050376  2017-03-09T09:06:16Z
#
#        last_modified_t last_modified_datetime  \
# 0           1474103893   2016-09-17T09:18:13Z
# 1           1489069957   2017-03-09T14:32:37Z
# 2           1489069957   2017-03-09T14:32:37Z
# 3           1489055731   2017-03-09T10:35:31Z
# 4           1489055653   2017-03-09T10:34:13Z
# ...                ...                    ...
# 65136       1489050383   2017-03-09T09:06:23Z
# 65137       1489057901   2017-03-09T11:11:41Z
# 65138       1489057828   2017-03-09T11:10:28Z
# 65139       1489061505   2017-03-09T12:11:45Z
# 65140       1489050376   2017-03-09T09:06:16Z
#
#                                             product_name generic_name  \
# 0                                     Farine de blé noir          NaN
# 1                         Banana Chips Sweetened (Whole)          NaN
# 2                                                Peanuts          NaN
# 3                                 Organic Salted Nut Mix          NaN
# 4                                        Organic Polenta          NaN
# ...                                                  ...          ...
# 65136                 Organic Soup, Hearty Tomato Bisque          NaN
# 65137            Organic Poblano Pepper And Corn Chowder          NaN
# 65138                     Organic Thai Sweet Potato Soup          NaN
# 65139  Organic Vegetable Lentil & Roasted Red Pepper ...          NaN
# 65140                Organic Soup, Chipotle Sweet Potato          NaN
#
#       quantity  ... fruits-vegetables-nuts_100g  \
# 0          1kg  ...                         NaN
# 1          NaN  ...                         NaN
# 2          NaN  ...                         NaN
# 3          NaN  ...                         NaN
# 4          NaN  ...                         NaN
# ...        ...  ...                         ...
# 65136      NaN  ...                         NaN
# 65137      NaN  ...                         NaN
# 65138      NaN  ...                         NaN
# 65139      NaN  ...                         NaN
# 65140      NaN  ...                         NaN
#
#       fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 65136                                  NaN                              NaN
# 65137                                  NaN                              NaN
# 65138                                  NaN                              NaN
# 65139                                  NaN                              NaN
# 65140                                  NaN                              NaN
#
#       cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# 0            NaN             NaN                   NaN
# 1            NaN             NaN                   NaN
# 2            NaN             NaN                   NaN
# 3            NaN             NaN                   NaN
# 4            NaN             NaN                   NaN
# ...          ...             ...                   ...
# 65136        NaN             NaN                   NaN
# 65137        NaN             NaN                   NaN
# 65138        NaN             NaN                   NaN
# 65139        NaN             NaN                   NaN
# 65140        NaN             NaN                   NaN
#
#       nutrition-score-fr_100g nutrition-score-uk_100g glycemic-index_100g  \
# 0                         NaN                     NaN                 NaN
# 1                        14.0                    14.0                 NaN
# 2                         0.0                     0.0                 NaN
# 3                        12.0                    12.0                 NaN
# 4                         NaN                     NaN                 NaN
# ...                       ...                     ...                 ...
# 65136                     4.0                     4.0                 NaN
# 65137                     5.0                     5.0                 NaN
# 65138                     2.0                     2.0                 NaN
# 65139                    -3.0                    -3.0                 NaN
# 65140                     NaN                     NaN                 NaN
#
#       water-hardness_100g
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 65136                 NaN
# 65137                 NaN
# 65138                 NaN
# 65139                 NaN
# 65140                 NaN
#
# [65141 rows x 163 columns]

# %%
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1       1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2       1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %%
food.shape[0] #prints number of observation
# Out:
# 6014

# %%
food.shape[1] #prints number of columns
# Out:
# 163

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %%
food.dtypes[104]
# Out:
# dtype('float64')

# %%
food.index
# Out:
# RangeIndex(start=0, stop=6014, step=1)

# %%
food["product_name"][18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
food.iloc[19:20,7:8] #rows columns
# Out:
#           product_name
# 19  Organic Oat Groats

# %%
food.iloc[19:20,food.columns=="product_name"]
# Out:
#           product_name
# 19  Organic Oat Groats

# %%
nc=food.isnull().sum()
nc
# Out:
# code                           0
# url                            0
# creator                        0
# created_t                      0
# created_datetime               0
#                            ...
# carbon-footprint_100g      65141
# nutrition-score-fr_100g    14344
# nutrition-score-uk_100g    14344
# glycemic-index_100g        65141
# water-hardness_100g        65141
# Length: 163, dtype: int64

# %%
food.isnull().sum()
# Out:
# code                          0
# url                           0
# creator                       0
# created_t                     0
# created_datetime              0
#                            ...
# carbon-footprint_100g      6014
# nutrition-score-fr_100g    1512
# nutrition-score-uk_100g    1512
# glycemic-index_100g        6014
# water-hardness_100g        6014
# Length: 163, dtype: int64
