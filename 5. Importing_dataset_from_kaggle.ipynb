# %% [markdown]
# <b> IMPORTING DATASETS THROUGH KAGGLE API </b>

# %%
#Import kaggle dataset using API
#We can do cmd commands using !
# !pip install kaggle

# %%
#Make sure you google colab account and kaggle account are same google account

# %%
# https://www.kaggle.com/competitions/LANL-Earthquake-Prediction

# %%
#Click on login icon and then account
#click new api toke
#then we have to upload this kaggle.json file in out google colab file

# %% [markdown]
# Upload your kaggle.json file

# %% [markdown]
# Now we have to configure the path of this json file

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake Dataset

# %%
#API to fetch the dataset from kaggle
#In data tab you can find the required command
#Make sure you accept the late submission button
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# LANL-Earthquake-Prediction.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#Extracting the compressed dataset
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'

with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import pandas as pd
data=pd.read_csv("/content/sample_submission.csv")

# %%
data
# Out:
#           seg_id  time_to_failure
# 0     seg_00030f                0
# 1     seg_0012b5                0
# 2     seg_00184e                0
# 3     seg_003339                0
# 4     seg_0042cc                0
# ...          ...              ...
# 2619  seg_ff4236                0
# 2620  seg_ff7478                0
# 2621  seg_ff79d9                0
# 2622  seg_ffbd6a                0
# 2623  seg_ffe7cc                0
#
# [2624 rows x 2 columns]

# %%
data.head(50)
# Out:
#         seg_id  time_to_failure
# 0   seg_00030f                0
# 1   seg_0012b5                0
# 2   seg_00184e                0
# 3   seg_003339                0
# 4   seg_0042cc                0
# 5   seg_004314                0
# 6   seg_004cd2                0
# 7   seg_004ee5                0
# 8   seg_004f1f                0
# 9   seg_00648a                0
# 10  seg_006e4a                0
# 11  seg_007a37                0
# 12  seg_00a37e                0
# 13  seg_00be11                0
# 14  seg_00c35b                0
# 15  seg_00cc91                0
# 16  seg_00e5f7                0
# 17  seg_00f3b9                0
# 18  seg_010eab                0
# 19  seg_0125d9                0
# 20  seg_0144cb                0
# 21  seg_0165c6                0
# 22  seg_016913                0
# 23  seg_016cdb                0
# 24  seg_017314                0
# 25  seg_01a8dc                0
# 26  seg_01c775                0
# 27  seg_01ecb0                0
# ...
